# %%
psnr_values_new = [
    [38.4933, 38.4844, 38.4924],
    [40.2144, 40.2528, 40.2087],
    [40.0677, 40.0666, 40.0676],
    [36.9838, 36.9899, 36.9639],
    [39.168, 39.1928, 39.1808],
    [38.3973, 38.3845, 38.4257],
    [38.6737, 38.7221, 38.7086],
    [37.3158, 37.2959, 37.3398],
    [37.5691, 37.5907, 37.5648],
    [38.8065, 38.8148, 38.8266],
    [38.6832, 38.7051, 38.6795],
    [37.6926, 37.747, 37.7408],
    [38.4248, 38.4237, 38.3951],
    [37.5139, 37.5131, 37.5492],
    [37.794, 37.7687, 37.7717],
    [37.6054, 37.6274, 37.5784],
    [38.2838, 38.2756, 38.2873],
    [39.6798, 39.6806, 39.6597],
    [39.5399, 39.5308, 39.5441],
    [36.9583, 36.9454, 36.9566],
    [38.8408, 38.8478, 38.8429],
    [38.1864, 38.2156, 38.2062],
    [38.4527, 38.4235, 38.4437],
    [37.2649, 37.2878, 37.2704],
    [35.195, 35.1554, 35.1519],
    [36.8104, 36.8652, 36.9174],
    [36.6875, 36.6434, 36.6837],
    [32.4283, 32.5888, 32.7153],
    [35.1413, 35.0623, 35.0844],
    [34.9496, 34.9041, 34.9819],
    [35.3145, 35.2132, 35.2498],
    [32.7938, 32.8934, 32.9555],
    [36.0337, 36.027, 36.0013],
    [36.918, 36.9173, 36.8692],
    [36.7989, 36.7951, 36.8033],
    [36.8681, 37.0039, 36.9374],
    [36.7639, 36.8234, 36.8117],
    [36.0451, 36.0578, 36.0496],
    [36.2128, 36.2014, 36.2402],
    [36.7375, 36.6049, 36.7034],
    [36.0607, 36.1364, 35.9962],
    [37.1874, 37.2095, 37.1772],
    [37.0408, 37.1032, 37.0792],
    [34.3578, 34.5589, 34.4033],
    [36.3394, 36.3319, 36.3213],
    [36.0253, 35.9554, 36.017],
    [36.2066, 36.2026, 36.1601],
    [34.7418, 34.8747, 34.7424],
    [38.0458, 38.0261, 36.1793],
    [39.6701, 39.6494, 39.6822],
    [39.4927, 39.501, 39.5024],
    [36.5286, 36.5252, 36.5288],
    [38.6459, 38.617, 38.6307],
    [37.9701, 37.9457, 37.9527],
    [38.2241, 38.2532, 38.2317],
    [36.845, 36.8947, 36.8427]
]

print(psnr_values_new)
images = ['Peppers', 'Lena', 'Airplane', 'Baboon', 'Barbara', 'Boat', 'Goldhill', 'Stream and bridges']
metaheuristics = ["SCA", "TLBO", "DE", "AOA", "ICA", "SSA", "WOA"]
# Out:
# [[38.4933, 38.4844, 38.4924], [40.2144, 40.2528, 40.2087], [40.0677, 40.0666, 40.0676], [36.9838, 36.9899, 36.9639], [39.168, 39.1928, 39.1808], [38.3973, 38.3845, 38.4257], [38.6737, 38.7221, 38.7086], [37.3158, 37.2959, 37.3398], [37.5691, 37.5907, 37.5648], [38.8065, 38.8148, 38.8266], [38.6832, 38.7051, 38.6795], [37.6926, 37.747, 37.7408], [38.4248, 38.4237, 38.3951], [37.5139, 37.5131, 37.5492], [37.794, 37.7687, 37.7717], [37.6054, 37.6274, 37.5784], [38.2838, 38.2756, 38.2873], [39.6798, 39.6806, 39.6597], [39.5399, 39.5308, 39.5441], [36.9583, 36.9454, 36.9566], [38.8408, 38.8478, 38.8429], [38.1864, 38.2156, 38.2062], [38.4527, 38.4235, 38.4437], [37.2649, 37.2878, 37.2704], [35.195, 35.1554, 35.1519], [36.8104, 36.8652, 36.9174], [36.6875, 36.6434, 36.6837], [32.4283, 32.5888, 32.7153], [35.1413, 35.0623, 35.0844], [34.9496, 34.9041, 34.9819], [35.3145, 35.2132, 35.2498], [32.7938, 32.8934, 32.9555], [36.0337, 36.027, 36.0013], [36.918, 36.9173, 36.8692], [36.7989, 36.7951
# ...

# %%
import matplotlib.pyplot as plt
import statistics
from math import sqrt


def plot_confidence_interval(x, values, z=1.96, color='#2187bb', horizontal_line_width=0.25):
    mean = statistics.mean(values)
    stdev = statistics.stdev(values)
    confidence_interval = z * stdev / sqrt(len(values))

    left = x - horizontal_line_width / 2
    top = mean - confidence_interval
    right = x + horizontal_line_width / 2
    bottom = mean + confidence_interval
    plt.plot([x, x], [top, bottom], color=color)
    plt.plot([left, right], [top, top], color=color)
    plt.plot([left, right], [bottom, bottom], color=color)
    plt.plot(x, mean, 'o', color='#f44336')

    return mean, confidence_interval

# %%
arr = []
cnt = 0
for i in range(len(psnr_values_new)):
    if cnt == len(metaheuristics):
        cnt = 0
    arr.append(metaheuristics[cnt])
    cnt += 1
for i in range(len(images)):
    plt.figure(figsize=(8, 4))
    plt.xticks([i for i in range(len(metaheuristics))], metaheuristics)
    plt.title(f'Confidence Interval {images[i]}')
    for metaheu in range(len(metaheuristics)):
        plot_confidence_interval(metaheu, psnr_values_new[metaheu* len(images) +i])
    plt.show()

# %%
capacity_conf = [
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126821, 126821, 126759],
    [126976, 126945, 126945],
    [126976, 126976, 126976],
    [126976, 126945, 126976],
    [126666, 126697, 126883],

    [122171, 121737, 121675],
    [125488, 125395, 125488],
    [125054, 125023, 125147],
    [85002, 85312, 84847],
    [116963, 116126, 116343],
    [120621, 120528, 120528],
    [121892, 121644, 121613],
    [95666, 95139, 94519],

    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126883, 126914, 126914],

    [125240, 125023, 124961],
    [126356, 126511, 126573],
    [126418, 126542, 126449],
    [95821, 96844, 97619],
    [121365, 121644, 121272],
    [124806, 124744, 124899],
    [124930, 124527, 124713],
    [104470, 105214, 105462],

    [120249, 120094, 119970],
    [124930, 123845, 124000],
    [124062, 124155, 124062],
    [76787, 78058, 75857],
    [113460, 114328, 112964],
    [117118, 117769, 112964],
    [118420, 119164, 118637],
    [87699, 86521, 88784],

    [120373, 125519, 125550],
    [126790, 126697, 126635],
    [126480, 126325, 126635],
    [107322, 108252, 106299],
    [123070, 123411, 123039],
    [124837, 124961, 125426],
    [125178, 125457, 125271],
    [112344, 112127, 112096],

    [125457, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126852, 126790, 126945],
    [126945, 126976, 126976],
    [126976, 126976, 126976],
    [126976, 126976, 126976],
    [126914, 126945, 126821]
]

for i in range(len(images)):
    plt.figure(figsize=(8, 4))
    plt.xticks([i for i in range(len(metaheuristics))], metaheuristics)
    plt.title(f'Confidence Interval {images[i]}')
    for metaheu in range(len(metaheuristics)):
        plot_confidence_interval(metaheu, capacity_conf[metaheu* len(images) +i])
    plt.show()

# %%
import pandas as pd

# Ваши данные
data = """
sca
peppers512.png 37.7431 0.999262 126976
lena512.png 39.1718 0.999323 126976
airplane512.png 39.0365 0.999353 126976
baboon512.png 36.5665 0.998875 126976
barbara512.png 38.3565 0.999452 126976
boat512.png 37.7 0.999174 126976
goldhill512.png 37.9716 0.999307 126976
stream_and_bridge512.png 36.8252 0.999289 126511
tlbo
peppers512.png 36.3801 0.999104 126635
lena512.png 37.5444 0.999161 126945
airplane512.png 37.411 0.999199 126914
baboon512.png 35.2088 0.998641 113987
barbara512.png 36.7715 0.999314 125085
boat512.png 36.287 0.998987 126604
goldhill512.png 36.4969 0.999143 126635
stream_and_bridge512.png 35.4414 0.99913 118079
ica
peppers512.png 35.515 0.99896 126077
lena512.png 36.5262 0.999011 126728
airplane512.png 36.4096 0.999056 126604
baboon512.png 35.3886 0.998674 109616
barbara512.png 36.1687 0.999242 122884
boat512.png 35.4956 0.998838 125457
goldhill512.png 35.6934 0.999016 125767
stream_and_bridge512.png 35.4514 0.99913 113119
aoa
peppers512.png 35.3703 0.99893 122512
lena512.png 36.4279 0.998993 125271
airplane512.png 36.3473 0.999046 125705
baboon512.png 36.3165 0.998911 72106
barbara512.png 36.1736 0.999247 113491
boat512.png 35.2746 0.998794 120280
goldhill512.png 35.5483 0.998988 121613
stream_and_bridge512.png 35.9508 0.999223 82739
ssa
peppers512.png 35.4694 0.998958 126945
lena512.png 36.4848 0.999008 126976
airplane512.png 36.3803 0.999055 126976
baboon512.png 34.8656 0.998518 126542
barbara512.png 35.9684 0.999213 126914
boat512.png 35.4067 0.99883 126976
goldhill512.png 35.6226 0.999009 126976
stream_and_bridge512.png 35.0353 0.99905 125922
woa
peppers512.png 34.7749 0.99909 126945
lena512.png 35.5909 0.999102 126976
airplane512.png 35.4946 0.999177 126976
baboon512.png 33.9785 0.998697 126449
barbara512.png 35.0994 0.999271 126883
boat512.png 34.7254 0.998992 126976
goldhill512.png 34.8737 0.999099 126976
stream_and_bridge512.png 34.1944 0.999123 125953
de
peppers512.png 36.9024 0.999166 126976
lena512.png 37.6119 0.999157 126976
airplane512.png 37.5222 0.999198 126976
baboon512.png 36.2052 0.998821 126976
barbara512.png 37.2124 0.99935 126976
boat512.png 36.8837 0.99907 126976
goldhill512.png 37.0064 0.999201 126976
stream_and_bridge512.png 36.3758 0.99924 126325
"""

# Разделение данных по строкам
lines = data.strip().split('\n')

# Создание списка словарей для данных
data_list = []
for line in lines:
    parts = line.split()
    print(parts)
    filename = parts[0]
    values = list(map(float, parts[1:]))
    if len(values):
        print(values)
        data_list.append({'Value1': values[0], 'Value2': values[1], 'Value3': values[2]})

# Создание DataFrame из списка словарей
df = pd.DataFrame(data_list)

# Сохранение DataFrame в Excel
df.to_excel('output_data.xlsx', index=False)
# Out:
# ['sca']
# ['peppers512.png', '37.7431', '0.999262', '126976']
# [37.7431, 0.999262, 126976.0]
# ['lena512.png', '39.1718', '0.999323', '126976']
# [39.1718, 0.999323, 126976.0]
# ['airplane512.png', '39.0365', '0.999353', '126976']
# [39.0365, 0.999353, 126976.0]
# ['baboon512.png', '36.5665', '0.998875', '126976']
# [36.5665, 0.998875, 126976.0]
# ['barbara512.png', '38.3565', '0.999452', '126976']
# [38.3565, 0.999452, 126976.0]
# ['boat512.png', '37.7', '0.999174', '126976']
# [37.7, 0.999174, 126976.0]
# ['goldhill512.png', '37.9716', '0.999307', '126976']
# [37.9716, 0.999307, 126976.0]
# ['stream_and_bridge512.png', '36.8252', '0.999289', '126511']
# [36.8252, 0.999289, 126511.0]
# ['tlbo']
# ['peppers512.png', '36.3801', '0.999104', '126635']
# [36.3801, 0.999104, 126635.0]
# ['lena512.png', '37.5444', '0.999161', '126945']
# [37.5444, 0.999161, 126945.0]
# ['airplane512.png', '37.411', '0.999199', '126914']
# [37.411, 0.999199, 126914.0]
# ...

# %% [markdown]
# ###-------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

# Задайте данные
images = ['Peppers', 'Lena', 'Airplane', 'Baboon', 'Barbara', 'Boat', 'Goldhill', 'Stream and bridges']
metaheuristics = ["SCA", "TLBO", "DE", "AOA", "ICA", "SSA", "WOA"]
psnr_values = [
    [38.49003333, 40.2253, 40.0673, 36.9792, 39.18053333, 38.4025, 38.70146667, 37.31716667],
    [37.57486667, 38.81596667, 38.68926667, 37.7268, 38.41453333, 37.5254, 37.77813333, 37.60373333],
    [38.28223333, 39.67336667, 39.53826667, 36.95343333, 38.84383333, 38.20273333, 38.43996667, 37.27436667],
    [35.16743333, 36.86433333, 36.67153333, 32.57746667, 35.096, 34.9452, 35.25916667, 32.8809],
    [36.02066667, 36.9015, 36.7991, 36.93646667, 36.79966667, 36.05083333, 36.21813333, 36.68193333],
    [36.06443333, 37.19136667, 37.0744, 34.44, 36.33086667, 35.99923333, 36.18976667, 34.7863],
    [37.41706667, 39.66723333, 39.4987, 36.52753333, 38.6312, 37.95616667, 38.23633333, 36.8608],
]

ssim_values = [
    [0.999372333, 0.999454667, 0.999474333, 0.998994, 0.999541, 0.999292667, 0.999411, 0.999372667],
    [0.999251333, 0.999304333, 0.999332333, 0.999102, 0.999467, 0.999161, 0.999295667, 0.999391333],
    [0.999333, 0.999387667, 0.999413667, 0.998962333, 0.999500333, 0.999249333, 0.999366, 0.999348667],
    [0.998881333, 0.999043, 0.999074333, 0.997828667, 0.999081333, 0.998716333, 0.998929, 0.998628667],
    [0.999035, 0.999059667, 0.999103, 0.998996333, 0.999314667, 0.998936667, 0.999093333, 0.999297333],
    [0.999027333, 0.999080667, 0.999117333, 0.998419667, 0.999240333, 0.998903667, 0.99907, 0.999006],
    [0.999225333, 0.999396333, 0.999417, 0.998914667, 0.999493667, 0.999234667, 0.999357667, 0.999318333],
]

capacity = [
    [126976, 126976, 126976, 126800.3333, 126955.3333, 126976, 126965.6667, 126748.6667],
    [121861, 125457, 125074.6667, 85053.66667, 116477.3333, 120559, 121716.3333, 95108],
    [126976, 126976, 126976, 126976, 126976, 126976, 126976, 126903.6667],
    [125074.6667, 126480, 126469.6667, 96761.33333, 121427, 124816.3333, 124723.3333, 105048.6667],
    [120104.3333, 124258.3333, 124093, 76900.66667, 113584, 115950.3333, 118740.3333, 87668],
    [123814, 126707.3333, 126480, 107291, 123173.3333, 125074.6667, 125302, 112189],
    [126469.6667, 126976, 126976, 126862.3333, 126965.6667, 126976, 126976, 126893.3333],
]

# Создайте гистограммы
plt.figure(figsize=(20, 6))

# Гистограмма PSNR
x = np.arange(len(images))
width = 0.13
for i in range(len(psnr_values)):
    plt.bar(x + i * width, psnr_values[i], width=width, label=f'{metaheuristics[i]}')
    plt.plot()

plt.xlabel('Images')
plt.ylabel('PSNR')
plt.xticks(x + width, images, rotation=45)
plt.title('PSNR Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.show()

# Гистограмма SSIM

plt.figure(figsize=(20, 6))
x = np.arange(len(images))
width = 0.13
for i in range(len(ssim_values)):
    plt.bar(x + i * width, ssim_values[i], width=width, label=f'{metaheuristics[i]}')

plt.xlabel('Images')
plt.ylabel('SSIM')
plt.xticks(x + width, images, rotation=45)
plt.title('SSIM Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.tight_layout()
plt.show()

# Гистограмма Сapacity

plt.figure(figsize=(20, 6))
x = np.arange(len(images))
width = 0.13
for i in range(len(capacity)):
    plt.bar(x + i * width, capacity[i], width=width, label=f'{metaheuristics[i]}')

plt.xlabel('Images')
plt.ylabel('Capacity')
plt.xticks(x + width, images, rotation=45)
plt.title('Capacity Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.show()

# %%
 # PSNR
psnr_values = np.array(psnr_values)
psnr_averages = np.mean(psnr_values, axis=1)

# SSIM
ssim_values = np.array(ssim_values)
ssim_averages = np.mean(ssim_values, axis=1)

# Capacity
capacity = np.array(capacity)
capacity_averages = np.mean(capacity, axis=1)

# %%
psnr_averages
# Out:
# array([38.6704375 , 38.0160875 , 38.401025  , 34.93275417, 36.5510375 ,
#        36.00954583, 38.09937917])

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, psnr_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('PSNR')
ax.set_title('PSNR Comprasion')
# Out:
# Text(0.5, 1.0, 'PSNR Comprasion')

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, ssim_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('SSIM')
ax.set_title('SSIM Comprasion')
# Out:
# Text(0.5, 1.0, 'SSIM Comprasion')

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, capacity_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Capacity')
ax.set_title('Capacity Comprasion')
# Out:
# Text(0.5, 1.0, 'Capacity Comprasion')

# %%
import pandas as pd

metaheuristics = ["SCA", "TLBO", "DE", "AOA", "ICA", "SSA", "WOA"]

data = {
    'Metaheuristic': metaheuristics,
    'PSNR Average': psnr_averages,
    'SSIM Average': ssim_averages,
    'Capacity Average': capacity_averages
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Metaheuristic  PSNR Average  SSIM Average  Capacity Average
# 0           SCA     38.670438      0.999364     126921.750000
# 1          TLBO     38.016087      0.999288     113913.374996
# 2            DE     38.401025      0.999320     126966.958337
# 3           AOA     34.932754      0.998773     118850.125004
# 4           ICA     36.551037      0.999105     110162.374984
# 5           SSA     36.009546      0.998983     121253.916663
# 6           WOA     38.099379      0.999295     126886.875000

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='PSNR Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['PSNR Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('PSNR')
ax.set_title('PSNR Comparison (Sorted)')

plt.show()

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='SSIM Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['SSIM Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('SSIM')
ax.set_title('SSIM Comparison (Sorted)')

plt.show()

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='Capacity Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['Capacity Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Capacity')
ax.set_title('Capacity Comparison (Sorted)')

plt.show()

# %%
psnr_values_new = [
    [37.7515, 37.7431],
    [39.1811, 39.1718],
    [39.0541, 39.0365],
    [36.5461, 36.5665],
    [38.3404, 38.3565],
    [37.7021, 37.7],
    [37.9548, 37.9716],
    [36.8526, 36.8252],

    [36.3648, 36.3801],
    [37.5682, 37.5444],
    [37.4205, 37.411],
    [35.2334, 35.2088],
    [36.7313, 36.7715],
    [36.2906, 36.287],
    [36.4738, 36.4969],
    [35.4089, 35.4414],

    [36.9133, 36.9024],
    [37.6122, 37.6119],
    [37.5247, 37.5222],
    [36.1539, 36.2052],
    [37.2114, 37.2124],
    [36.8908, 36.8837],
    [37.0002, 37.0064],
    [36.3747, 36.3758],

    [35.3658, 35.3703],
    [36.4636, 36.4279],
    [36.3083, 36.3473],
    [36.2562, 36.3165],
    [36.2161, 36.1736],
    [35.3129, 35.2746],
    [35.5013, 35.5483],
    [35.9597, 35.9508],

    [35.5313, 35.515],
    [36.5364, 36.5262],
    [36.4176, 36.4096],
    [35.3831, 35.3886],
    [36.1303, 36.1687],
    [35.5085, 35.4956],
    [35.7099, 35.6934],
    [35.4584, 35.4514],

    [35.4739, 35.4694],
    [36.5153, 36.4848],
    [36.3593, 36.3803],
    [34.8759, 34.8656],
    [35.9629, 35.9684],
    [35.4114, 35.4067],
    [35.6117, 35.6226],
    [35.0272, 35.0353],

    [34.7831, 34.7749],
    [35.6385, 35.5909],
    [35.5189, 35.4946],
    [33.9766, 33.9785],
    [35.0781, 35.0994],
    [34.7281, 34.7254],
    [34.894, 34.8737],
    [34.1683, 34.1944],
]
print(psnr_values_new)
images = ['Peppers', 'Lena', 'Airplane', 'Baboon', 'Barbara', 'Boat', 'Goldhill', 'Stream and bridges']
# metaheuristics = ["SCA", "TLBO", "ICA", "AOA", "SSA", "WOA", "DE"]
metaheuristics = ["SCA", "TLBO", "DE", "AOA", "ICA", "SSA", "WOA"]
# Out:
# [[37.7515, 37.7431], [39.1811, 39.1718], [39.0541, 39.0365], [36.5461, 36.5665], [38.3404, 38.3565], [37.7021, 37.7], [37.9548, 37.9716], [36.8526, 36.8252], [36.3648, 36.3801], [37.5682, 37.5444], [37.4205, 37.411], [35.2334, 35.2088], [36.7313, 36.7715], [36.2906, 36.287], [36.4738, 36.4969], [35.4089, 35.4414], [36.9133, 36.9024], [37.6122, 37.6119], [37.5247, 37.5222], [36.1539, 36.2052], [37.2114, 37.2124], [36.8908, 36.8837], [37.0002, 37.0064], [36.3747, 36.3758], [35.3658, 35.3703], [36.4636, 36.4279], [36.3083, 36.3473], [36.2562, 36.3165], [36.2161, 36.1736], [35.3129, 35.2746], [35.5013, 35.5483], [35.9597, 35.9508], [35.5313, 35.515], [36.5364, 36.5262], [36.4176, 36.4096], [35.3831, 35.3886], [36.1303, 36.1687], [35.5085, 35.4956], [35.7099, 35.6934], [35.4584, 35.4514], [35.4739, 35.4694], [36.5153, 36.4848], [36.3593, 36.3803], [34.8759, 34.8656], [35.9629, 35.9684], [35.4114, 35.4067], [35.6117, 35.6226], [35.0272, 35.0353], [34.7831, 34.7749], [35.6385, 35.5909], [35.5189, 35.4946], [33.9766, 33.9785], [35.0781, 35.0994], [34.7281, 34.7254], [34.894, 34.8737], [34.1683, 34.1944]]

# %%
import matplotlib.pyplot as plt
import statistics
from math import sqrt


def plot_confidence_interval(x, values, z=1.96, color='#2187bb', horizontal_line_width=0.25):
    mean = statistics.mean(values)
    stdev = statistics.stdev(values)
    confidence_interval = z * stdev / sqrt(len(values))

    left = x - horizontal_line_width / 2
    top = mean - confidence_interval
    right = x + horizontal_line_width / 2
    bottom = mean + confidence_interval
    plt.plot([x, x], [top, bottom], color=color)
    plt.plot([left, right], [top, top], color=color)
    plt.plot([left, right], [bottom, bottom], color=color)
    plt.plot(x, mean, 'o', color='#f44336')

    return mean, confidence_interval

# %%
arr = []
cnt = 0
for i in range(len(psnr_values_new)):
    if cnt == len(metaheuristics):
        cnt = 0
    arr.append(metaheuristics[cnt])
    cnt += 1
for i in range(len(images)):
    plt.figure(figsize=(8, 4))
    plt.xticks([i for i in range(len(metaheuristics))], metaheuristics)
    plt.title(f'Confidence Interval {images[i]}')
    for metaheu in range(len(metaheuristics)):
        plot_confidence_interval(metaheu, psnr_values_new[metaheu* len(images) +i])
    plt.show()

# %%
capacity_conf = [
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126511, 126511],

    [126666, 126635],
    [126914, 126945],
    [126945, 126914],
    [113956, 113987],
    [125364, 125085],
    [126635, 126604],
    [126635, 126635],
    [118172, 118079],

    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126976, 126976],
    [126356, 126325],

    [122884, 122512],
    [125209, 125271],
    [125209, 125705],
    [69657, 72106],
    [113274, 113491],
    [120714, 120280],
    [121489, 121613],
    [82863, 82739],

    [126108, 126077],
    [126759, 126728],
    [126635, 126604],
    [109306, 109616],
    [123411, 122884],
    [125364, 125457],
    [125457, 125767],
    [113491, 113119],

    [126914, 126945],
    [126976, 126976],
    [126976, 126976],
    [126201, 126542],
    [126945, 126914],
    [126976, 126976],
    [126976, 126976],
    [125736, 125922],

    [126976, 126945],
    [126976, 126976],
    [126976, 126976],
    [126480, 126449],
    [126945, 126883],
    [126976, 126976],
    [126976, 126976],
    [126077, 125953],

]
for i in range(len(images)):
    plt.figure(figsize=(8, 4))
    plt.xticks([i for i in range(len(metaheuristics))], metaheuristics)
    plt.title(f'Confidence Interval {images[i]}')
    for metaheu in range(len(metaheuristics)):
        plot_confidence_interval(metaheu, capacity_conf[metaheu* len(images) +i])
    plt.show()

# %% [markdown]
# ###-------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

# Задайте данные
images = ['Peppers', 'Lena', 'Airplane', 'Baboon', 'Barbara', 'Boat', 'Goldhill', 'Stream and bridges']
metaheuristics = ["SCA", "TLBO", "DE", "AOA", "ICA", "SSA", "WOA"]

psnr_values = [
    [37.7473, 39.17645, 39.0453, 36.5563, 38.34845, 37.70105, 37.9632, 36.8389],
    [36.37245, 37.5563, 37.41575, 35.2211, 36.7514, 36.2888, 36.48535, 35.42515],
    [36.90785, 37.61205, 37.52345, 36.17955, 37.2119, 36.88725, 37.0033, 36.37525],
    [35.36805, 36.44575, 36.3278, 36.28635, 36.19485, 35.29375, 35.5248, 35.95525],
    [35.52315, 36.5313, 36.4136, 35.38585, 36.1495, 35.50205, 35.70165, 35.4549],
    [35.47165, 36.50005, 36.3698, 34.87075, 35.96565, 35.40905, 35.61715, 35.03125],
    [34.779, 35.6147, 35.50675, 33.97755, 35.08875, 34.72675, 34.88385, 34.18135],
]

ssim_values = [
    [0.9992615, 0.9993245, 0.9993545, 0.9988755, 0.9994505, 0.999173, 0.999307, 0.999291],
    [0.999102, 0.999163, 0.999199, 0.9986435, 0.999311, 0.9989875, 0.99914, 0.999127],
    [0.9991655, 0.999158, 0.9991985, 0.9988155, 0.999351, 0.9990705, 0.9992, 0.9992375],
    [0.998931, 0.998999, 0.999042, 0.9989075, 0.999251, 0.9987965, 0.9989855, 0.9992225],
    [0.9989615, 0.999013, 0.9990575, 0.9986755, 0.9992395, 0.9988425, 0.9990185, 0.999128],
    [0.9989575, 0.9990105, 0.9990545, 0.998521, 0.9992125, 0.99883, 0.999007, 0.9990495],
    [0.999089, 0.9991085, 0.9991765, 0.9986955, 0.9992685, 0.9989905, 0.999099, 0.9991235],
]

capacity = [
    [126976, 126976, 126976, 126976, 126976, 126976, 126976, 126511],
    [126650.5, 126929.5, 126929.5, 113971.5, 125224.5, 126619.5, 126635, 118125.5],
    [126976, 126976, 126976, 126976, 126976, 126976, 126976, 126340.5],
    [122698, 125240, 125457, 70881.5, 113382.5, 120497, 121551, 82801],
    [126092.5, 126743.5, 126619.5, 109461, 123147.5, 125410.5, 125612, 113305],
    [126929.5, 126976, 126976, 126371.5, 126929.5, 126976, 126976, 125829],
    [126960.5, 126976, 126976, 126464.5, 126914, 126976, 126976, 126015],
]

# Создайте гистограммы
plt.figure(figsize=(20, 6))

# Гистограмма PSNR
x = np.arange(len(images))
width = 0.13
for i in range(len(psnr_values)):
    plt.bar(x + i * width, psnr_values[i], width=width, label=f'{metaheuristics[i]}')
    plt.plot()

plt.xlabel('Images')
plt.ylabel('PSNR')
plt.xticks(x + width, images, rotation=45)
plt.title('PSNR Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.show()

# Гистограмма SSIM

plt.figure(figsize=(20, 6))
x = np.arange(len(images))
width = 0.13
for i in range(len(ssim_values)):
    plt.bar(x + i * width, ssim_values[i], width=width, label=f'{metaheuristics[i]}')

plt.xlabel('Images')
plt.ylabel('SSIM')
plt.xticks(x + width, images, rotation=45)
plt.title('SSIM Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.tight_layout()
plt.show()

# Гистограмма Сapacity

plt.figure(figsize=(20, 6))
x = np.arange(len(images))
width = 0.13
for i in range(len(capacity)):
    plt.bar(x + i * width, capacity[i], width=width, label=f'{metaheuristics[i]}')

plt.xlabel('Images')
plt.ylabel('Capacity')
plt.xticks(x + width, images, rotation=45)
plt.title('Capacity Comparison')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.show()

# %%
 # PSNR
psnr_values = np.array(psnr_values)
psnr_averages = np.mean(psnr_values, axis=1)

# SSIM
ssim_values = np.array(ssim_values)
ssim_averages = np.mean(ssim_values, axis=1)

# Capacity
capacity = np.array(capacity)
capacity_averages = np.mean(capacity, axis=1)

# %%
psnr_averages
# Out:
# array([37.92211875, 36.4395375 , 36.962575  , 35.924575  , 35.83275   ,
#        35.65441875, 34.8448375 ])

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, psnr_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('PSNR')
ax.set_title('PSNR Comprasion')
# Out:
# Text(0.5, 1.0, 'PSNR Comprasion')

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, ssim_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('SSIM')
ax.set_title('SSIM Comprasion')
# Out:
# Text(0.5, 1.0, 'SSIM Comprasion')

# %%
fig, ax = plt.subplots()

# Example data
y_pos = np.arange(len(metaheuristics))

ax.barh(y_pos, capacity_averages, align='center')
ax.set_yticks(y_pos, labels=metaheuristics)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Capacity')
ax.set_title('Capacity Comprasion')
# Out:
# Text(0.5, 1.0, 'Capacity Comprasion')

# %%
import pandas as pd

metaheuristics = ["SCA", "TLBO", "ICA", "AOA", "SSA", "WOA", "DE"]

data = {
    'Metaheuristic': metaheuristics,
    'PSNR Average': psnr_averages,
    'SSIM Average': ssim_averages,
    'Capacity Average': capacity_averages
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Metaheuristic  PSNR Average  SSIM Average  Capacity Average
# 0           SCA     37.922119      0.999255       126917.8750
# 1          TLBO     36.439538      0.999084       123885.6875
# 2           ICA     36.962575      0.999150       126896.5625
# 3           AOA     35.924575      0.999017       110313.5000
# 4           SSA     35.832750      0.998992       122048.9375
# 5           WOA     35.654419      0.998955       126745.4375
# 6            DE     34.844837      0.999069       126782.2500

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='PSNR Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['PSNR Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('PSNR')
ax.set_title('PSNR Comparison (Sorted)')

plt.show()

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='SSIM Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['SSIM Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('SSIM')
ax.set_title('SSIM Comparison (Sorted)')

plt.show()

# %%
# Сортируйте DataFrame по значению PSNR Average
df = df.sort_values(by='Capacity Average', ascending=False)

# Постройте график
fig, ax = plt.subplots()

# Example data
y_pos = range(len(df))

ax.barh(y_pos, df['Capacity Average'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Metaheuristic'])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Capacity')
ax.set_title('Capacity Comparison (Sorted)')

plt.show()
